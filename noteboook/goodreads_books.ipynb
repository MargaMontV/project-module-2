# %%
import pandas as pd

# %%
# Pandas display options
pd.set_option('display.max_columns', None)

# %%
books = pd.read_csv('./Downloads/books.csv')
books
# Out:
#       bookID                                              title  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...
# 1          2  Harry Potter and the Order of the Phoenix (Har...
# 2          4  Harry Potter and the Chamber of Secrets (Harry...
# 3          5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4          8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...      ...                                                ...
# 11122  45631   Expelled from Eden: A William T. Vollmann Reader
# 11123  45633                        You Bright and Risen Angels
# 11124  45634                    The Ice-Shirt (Seven Dreams #1)
# 11125  45639                                        Poor People
# 11126  45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  object
#  1   title               11098 non-null  object
#  2   authors             11098 non-null  object
#  3   average_rating      11098 non-null  float64
#  4   isbn                11098 non-null  object
#  5   isbn13              11098 non-null  float64
#  6   language_code       11098 non-null  object
#  7     num_pages         11098 non-null  float64
#  8   ratings_count       11098 non-null  float64
#  9   text_reviews_count  11098 non-null  float64
#  10  publication_date    11098 non-null  object
#  11  publisher;;;        11098 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 1.0+ MB

# %%
books.columns = ['Book ID', 'Book title', 'Author', 'Average rating', 'ISBN', 'ISBN 13', 'Language', 'Nº of pages', 'Nº of ratings', 'Nº of reviews', 'Publication date', 'Publisher']
books.head()
# Out:
#   Book ID                                         Book title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author  Average rating        ISBN       ISBN 13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9.780440e+12
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9.780439e+12
# 2                J.K. Rowling            4.42  0439554896  9.780440e+12
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9.780440e+12
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9.780440e+12
#
#   Language  Nº of pages  Nº of ratings  Nº of reviews Publication date  \
# 0      eng        652.0      2095690.0        27591.0        9/16/2006
# ...

# %%
books_2 = books[books['ISBN 13'].notna()]
books_2.head()
# Out:
#   Book ID                                         Book title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author  Average rating        ISBN       ISBN 13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9.780440e+12
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9.780439e+12
# 2                J.K. Rowling            4.42  0439554896  9.780440e+12
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9.780440e+12
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9.780440e+12
#
#   Language  Nº of pages  Nº of ratings  Nº of reviews Publication date  \
# 0      eng        652.0      2095690.0        27591.0        9/16/2006
# ...

# %%
books_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11098 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Book ID           11098 non-null  object
#  1   Book title        11098 non-null  object
#  2   Author            11098 non-null  object
#  3   Average rating    11098 non-null  float64
#  4   ISBN              11098 non-null  object
#  5   ISBN 13           11098 non-null  float64
#  6   Language          11098 non-null  object
#  7   Nº of pages       11098 non-null  float64
#  8   Nº of ratings     11098 non-null  float64
#  9   Nº of reviews     11098 non-null  float64
#  10  Publication date  11098 non-null  object
#  11  Publisher         11098 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 1.1+ MB

# %%
#print(list(books_2['Author']))

# %%
#print(list(books_2['Book title']))

# %%
#print(list(books_2['Publisher']))

# %%
#print(list(books_2['Publication date']))

# %%
#print(list(books_2['Nº of pages']))

# %%
#print(list(books_2['Average rating']))

# %%
print(list(books_2['ISBN 13']))
# Out:
# [9780439785969.0, 9780439358071.0, 9780439554893.0, 9780439655484.0, 9780439682589.0, 9780439827607.0, 9780517226957.0, 9780345453747.0, 9781400052929.0, 9780739322208.0, 9780517149256.0, 9780767908184.0, 9780767915069.0, 9780767910439.0, 9780767903868.0, 9780767903820.0, 9780060920081.0, 9780380713806.0, 9780380727506.0, 9780380715435.0, 9780345538376.0, 9780618517657.0, 9780618346257.0, 9780618260584.0, 9780618391004.0, 9780618510825.0, 9780976694007.0, 9780689840920.0, 9780385326506.0, 9781575606248.0, 9781595580276.0, 9781595962805.0, 9780670059676.0, 9780141312620.0, 9780595321803.0, 9781590301944.0, 9780449146972.0, 9780061159176.0, 9780060762735.0, 9780060749910.0, 9780273704744.0, 9781932386103.0, 9780374517199.0, 9780374280390.0, 9780374519742.0, 9780374522599.0, 9780374518738.0, 9780374522872.0, 9780374519322.0, 9780374516000.0, 9780374520656.0, 9780822205104.0, 9780679734994.0, 9781596670235.0, 9781581807745.0, 9780800793616.0, 9780871202864.0, 9780753454947.0, 97808712099
# ...

# %%
#print(list(books_2['Language']))

# %%
books_2['ISBN 13'] = books_2['ISBN 13'].round()
books_2['Nº of pages'] = books_2['Nº of pages'].astype(int)
books_2['Nº of ratings'] = books_2['Nº of ratings'].astype(int)
books_2['Nº of reviews'] = books_2['Nº of reviews'].astype(int)
books_2.head()
# Out:
# C:\Users\Margarita\AppData\Local\Temp\ipykernel_18960\1868261061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books_2['ISBN 13'] = books_2['ISBN 13'].round()
# C:\Users\Margarita\AppData\Local\Temp\ipykernel_18960\1868261061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books_2['Nº of pages'] = books_2['Nº of pages'].astype(int)
# C:\Users\Margarita\AppData\Local\Temp\ipykernel_18960\1868261061.py:3: SettingWithCopyWarning:
# ...

# %%
books_3 = books_2[['Book title', 'Author', 'Average rating', 'ISBN 13', 
    'Nº of pages', 'Nº of ratings', 'Nº of reviews', 'Publication date']]
books_3.head()
